# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

housing = fetch_california_housing()

X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target)
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

# %%
input_ = keras.layers.Input(shape=X_train.shape[1:])
hidden1 = keras.layers.Dense(30, activation="relu")(input_)
hidden2 = keras.layers.Dense(30, activation="relu")(hidden1)
concat = keras.layers.concatenate([input_, hidden2])
output = keras.layers.Dense(1)(concat)
model = keras.models.Model(inputs=[input_], outputs=[output])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 30)           270         input_5[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 30)           930         dense_10[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 38)           0           input_5[0][0]
#                                                                  dense_11[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1)            39          concatenate_2[0][0]
# ==================================================================================================
# Total params: 1,239
# Trainable params: 1,239
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# better to visualise the model by plotting it - especially for functional API models

# %%
keras.utils.plot_model(model, "diagrams/03_test.png", show_shapes=True)

# %%
model.compile(loss="mean_squared_error", optimizer=keras.optimizers.SGD(lr=1e-3))
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/20
# 11610/11610 [==============================] - 1s 48us/sample - loss: 2.4724 - val_loss: 0.9370
# Epoch 2/20
# 11610/11610 [==============================] - 0s 30us/sample - loss: 0.9394 - val_loss: 0.7137
# Epoch 3/20
# 11610/11610 [==============================] - 0s 31us/sample - loss: 0.7040 - val_loss: 0.6507
# Epoch 4/20
# 11610/11610 [==============================] - 0s 30us/sample - loss: 0.6429 - val_loss: 0.6274
# Epoch 5/20
# 11610/11610 [==============================] - 0s 30us/sample - loss: 0.6082 - val_loss: 0.5983
# Epoch 6/20
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.5849 - val_loss: 0.5780
# Epoch 7/20
# 11610/11610 [==============================] - 0s 31us/sample - loss: 0.5675 - val_loss: 0.5596
# Epoch 8/20
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.5520 - val_loss: 0.5447
# Epoch 9/20
# 11610/11610 [==============================] - 0s 30us/sample - loss: 0.5425 - val_loss: 0.5333
# Epoch 10/20
# 11610/11610 [==============================] - 0s 30us/sample - loss: 0.5314 - val_loss: 0.5268
# Epoch 11/20
# 11610/11610 [==============================] - 0s 27us/sample - loss: 0.5224 - val_loss: 0.5170
# Epoch 12/20
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.5139 - val_loss: 0.5100
# Epoch 13/20
# 11610/11610 [==============================] - 0s 31us/sample - loss: 0.5068 - val_loss: 0.5021
# Epoch 14/20
# 11610/11610 [==============================] - 0s 27us/sample - loss: 0.5034 - val_loss: 0.4971
# Epoch 15/20
# 11610/11610 [==============================] - 0s 30us/sample - loss: 0.4978 - val_loss: 0.4911
# Epoch 16/20
# 11610/11610 [==============================] - 0s 30us/sample - loss: 0.4909 - val_loss: 0.4896
# Epoch 17/20
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.4910 - val_loss: 0.4823
# Epoch 18/20
# 11610/11610 [==============================] - 0s 30us/sample - loss: 0.4844 - val_loss: 0.4796
# Epoch 19/20
# 11610/11610 [==============================] - 0s 30us/sample - loss: 0.4813 - val_loss: 0.4736
# Epoch 20/20
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.4799 - val_loss: 0.4714

# %%
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()

# %%
mse_test = model.evaluate(X_test, y_test)
mse_test
# Out:
# 5160/5160 [==============================] - 0s 14us/sample - loss: 0.4854
# 0.48543088052623956

# %%
X_new = X_test[:3] # pretend these are new instances
y_pred = model.predict(X_new)
y_pred
# Out:
# array([[0.92094857],
#        [5.3209457 ],
#        [2.2590456 ]], dtype=float32)

# %%
model.save("keras_models/03_functional_API.h5")
