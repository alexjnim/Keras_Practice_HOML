# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

housing = fetch_california_housing()

X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target)
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

# %%
model = keras.models.Sequential([
            keras.layers.Dense(30, activation="relu", input_shape=X_train.shape[1:]),
            keras.layers.Dense(1)
                                ])


model.compile(loss="mean_squared_error", optimizer="sgd", metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 30)                270
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 31
# ...
# Total params: 301
# Trainable params: 301
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model, "diagrams/02_test.png", show_shapes=True)

# %%
history = model.fit(X_train, y_train, epochs=5,
                    validation_data=(X_valid, y_valid))
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/5
# 11610/11610 [==============================] - 1s 46us/sample - loss: 0.8242 - accuracy: 0.0026 - val_loss: 0.5505 - val_accuracy: 0.0039
# Epoch 2/5
# 11610/11610 [==============================] - 0s 30us/sample - loss: 1.3948 - accuracy: 0.0026 - val_loss: 0.4804 - val_accuracy: 0.0039
# Epoch 3/5
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.4445 - accuracy: 0.0027 - val_loss: 0.4380 - val_accuracy: 0.0039
# Epoch 4/5
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.4169 - accuracy: 0.0027 - val_loss: 0.4275 - val_accuracy: 0.0039
# Epoch 5/5
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.4042 - accuracy: 0.0027 - val_loss: 0.4451 - val_accuracy: 0.0039

# %%
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()

# %% [markdown]
# you can keep training the model by running .fit() again - this will keep the previous weights and keep improving it

# %%
history = model.fit(X_train, y_train, epochs=5,
                    validation_data=(X_valid, y_valid))
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/5
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.4157 - accuracy: 0.0027 - val_loss: 0.4089 - val_accuracy: 0.0039
# Epoch 2/5
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3911 - accuracy: 0.0028 - val_loss: 0.4167 - val_accuracy: 0.0039
# Epoch 3/5
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3871 - accuracy: 0.0028 - val_loss: 0.3983 - val_accuracy: 0.0039
# Epoch 4/5
# 11610/11610 [==============================] - 0s 29us/sample - loss: 0.3800 - accuracy: 0.0028 - val_loss: 0.4003 - val_accuracy: 0.0039
# Epoch 5/5
# 11610/11610 [==============================] - 0s 28us/sample - loss: 0.3768 - accuracy: 0.0028 - val_loss: 0.4015 - val_accuracy: 0.0039

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()

# %%
mse_test = model.evaluate(X_test, y_test)
mse_test
# Out:
# 5160/5160 [==============================] - 0s 16us/sample - loss: 0.3941 - accuracy: 0.0029
# [0.3940618190885514, 0.0029069767]

# %%
X_new = X_test[:3] # pretend these are new instances
y_pred = model.predict(X_new)
y_pred
# Out:
# array([[1.9687468],
#        [1.9456623],
#        [1.7840619]], dtype=float32)

# %%
model.save("keras_models/02_sequential_API_regressor.h5")
